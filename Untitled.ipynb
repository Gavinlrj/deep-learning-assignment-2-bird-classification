# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers,models
from keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import Model
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.applications.resnet50 import preprocess_input

from pathlib import Path
import os.path
import matplotlib.cm as cm
import cv2
import seaborn as sns
sns.set_style('darkgrid')
# Metrics
from sklearn.metrics import classification_report, confusion_matrix
import itertools
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.applications.resnet50 import preprocess_input


import os
import random
from pathlib import Path
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

# ... rest of your code ...

# %%
### create helper function
### We create a bunch of helpful functions throughout the course.
### Storing them here so they're easily accessible.

# Create a function to import an image and resize it to be able to be used with our model
def load_and_prep_image(filename, img_shape=224, scale=True):
  """
  Reads in an image from filename, turns it into a tensor and reshapes into
  (224, 224, 3).

  Parameters
  ----------
  filename (str): string filename of target image
  img_shape (int): size to resize target image to, default 224
  scale (bool): whether to scale pixel values to range(0, 1), default True
  """
  # Read in the image
  img = tf.io.read_file(filename)
  # Decode it into a tensor
  img = tf.image.decode_jpeg(img)
  # Resize the image
  img = tf.image.resize(img, [img_shape, img_shape])
  if scale:
    # Rescale the image (get all values between 0 and 1)
    return img/255.
  else:
    return img

# Note: The following confusion matrix code is a remix of Scikit-Learn's 
# plot_confusion_matrix function - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html
import itertools
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15, norm=False, savefig=False): 
  """Makes a labelled confusion matrix comparing predictions and ground truth labels.

  If classes is passed, confusion matrix will be labelled, if not, integer class values
  will be used.

  Args:
    y_true: Array of truth labels (must be same shape as y_pred).
    y_pred: Array of predicted labels (must be same shape as y_true).
    classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
    figsize: Size of output figure (default=(10, 10)).
    text_size: Size of output figure text (default=15).
    norm: normalize values or not (default=False).
    savefig: save confusion matrix to file (default=False).
  
  Returns:
    A labelled confusion matrix plot comparing y_true and y_pred.

  Example usage:
    make_confusion_matrix(y_true=test_labels, # ground truth test labels
                          y_pred=y_preds, # predicted labels
                          classes=class_names, # array of class label names
                          figsize=(15, 15),
                          text_size=10)
  """  
  # Create the confustion matrix
  cm = confusion_matrix(y_true, y_pred)
  cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
  n_classes = cm.shape[0] # find the number of classes we're dealing with

  # Plot the figure and make it pretty
  fig, ax = plt.subplots(figsize=figsize)
  cax = ax.matshow(cm, cmap=plt.cm.Blues) # colors will represent how 'correct' a class is, darker == better
  fig.colorbar(cax)

  # Are there a list of classes?
  if classes:
    labels = classes
  else:
    labels = np.arange(cm.shape[0])
  
  # Label the axes
  ax.set(title="Confusion Matrix",
         xlabel="Predicted label",
         ylabel="True label",
         xticks=np.arange(n_classes), # create enough axis slots for each class
         yticks=np.arange(n_classes), 
         xticklabels=labels, # axes will labeled with class names (if they exist) or ints
         yticklabels=labels)
  
  # Make x-axis labels appear on bottom
  ax.xaxis.set_label_position("bottom")
  ax.xaxis.tick_bottom()

  # Set the threshold for different colors
  threshold = (cm.max() + cm.min()) / 2.

  # Plot the text on each cell
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if norm:
      plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)
    else:
      plt.text(j, i, f"{cm[i, j]}",
              horizontalalignment="center",
              color="white" if cm[i, j] > threshold else "black",
              size=text_size)

  # Save the figure to the current working directory
  if savefig:
    fig.savefig("confusion_matrix.png")
  
# Make a function to predict on images and plot them (works with multi-class)
def pred_and_plot(model, filename, class_names):
  """
  Imports an image located at filename, makes a prediction on it with
  a trained model and plots the image with the predicted class as the title.
  """
  # Import the target image and preprocess it
  img = load_and_prep_image(filename)

  # Make a prediction
  pred = model.predict(tf.expand_dims(img, axis=0))

  # Get the predicted class
  if len(pred[0]) > 1: # check for multi-class
    pred_class = class_names[pred.argmax()] # if more than one output, take the max
  else:
    pred_class = class_names[int(tf.round(pred)[0][0])] # if only one output, round

  # Plot the image and predicted class
  plt.imshow(img)
  plt.title(f"Prediction: {pred_class}")
  plt.axis(False);
  
import datetime

def create_tensorboard_callback(dir_name, experiment_name):
  """
  Creates a TensorBoard callback instand to store log files.

  Stores log files with the filepath:
    "dir_name/experiment_name/current_datetime/"

  Args:
    dir_name: target directory to store TensorBoard log files
    experiment_name: name of experiment directory (e.g. efficientnet_model_1)
  """
  log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir
  )
  print(f"Saving TensorBoard log files to: {log_dir}")
  return tensorboard_callback

# Plot the validation and training data separately
import matplotlib.pyplot as plt

def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.

  Args:
    history: TensorFlow model History object (see: https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/History)
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

def compare_historys(original_history, new_history, initial_epochs=5):
    """
    Compares two TensorFlow model History objects.
    
    Args:
      original_history: History object from original model (before new_history)
      new_history: History object from continued model training (after original_history)
      initial_epochs: Number of epochs in original_history (new_history plot starts from here) 
    """
    
    # Get original history measurements
    acc = original_history.history["accuracy"]
    loss = original_history.history["loss"]

    val_acc = original_history.history["val_accuracy"]
    val_loss = original_history.history["val_loss"]

    # Combine original history with new history
    total_acc = acc + new_history.history["accuracy"]
    total_loss = loss + new_history.history["loss"]

    total_val_acc = val_acc + new_history.history["val_accuracy"]
    total_val_loss = val_loss + new_history.history["val_loss"]

    # Make plots
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(total_acc, label='Training Accuracy')
    plt.plot(total_val_acc, label='Validation Accuracy')
    plt.plot([initial_epochs-1, initial_epochs-1],
              plt.ylim(), label='Start Fine Tuning') # reshift plot around epochs
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(2, 1, 2)
    plt.plot(total_loss, label='Training Loss')
    plt.plot(total_val_loss, label='Validation Loss')
    plt.plot([initial_epochs-1, initial_epochs-1],
              plt.ylim(), label='Start Fine Tuning') # reshift plot around epochs
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.xlabel('epoch')
    plt.show()
  
# Create function to unzip a zipfile into current working directory 
# (since we're going to be downloading and unzipping a few files)
import zipfile

def unzip_data(filename):
  """
  Unzips filename into the current working directory.

  Args:
    filename (str): a filepath to a target zip folder to be unzipped.
  """
  zip_ref = zipfile.ZipFile(filename, "r")
  zip_ref.extractall()
  zip_ref.close()

# Walk through an image classification directory and find out how many files (images)
# are in each subdirectory.
import os

def walk_through_dir(dir_path):
  """
  Walks through dir_path returning its contents.

  Args:
    dir_path (str): target directory
  
  Returns:
    A print out of:
      number of subdiretories in dir_path
      number of images (files) in each subdirectory
      name of each subdirectory
  """
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
    
# Function to evaluate: accuracy, precision, recall, f1-score
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def calculate_results(y_true, y_pred):
  """
  Calculates model accuracy, precision, recall and f1 score of a binary classification model.

  Args:
      y_true: true labels in the form of a 1D array
      y_pred: predicted labels in the form of a 1D array

  Returns a dictionary of accuracy, precision, recall, f1-score.
  """
  # Calculate model accuracy
  model_accuracy = accuracy_score(y_true, y_pred) * 100
  # Calculate model precision, recall and f1 score using "weighted average
  model_precision, model_recall, model_f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted")
  model_results = {"accuracy": model_accuracy,
                  "precision": model_precision,
                  "recall": model_recall,
                  "f1": model_f1}
  return model_results

# %%
import os

def walk_through_dir(dir_path):
  """
  Walks through dir_path returning its contents.

  Args:
    dir_path (str): target directory
  
  Returns:
    A print out of:
      number of subdiretories in dir_path
      number of images (files) in each subdirectory
      name of each subdirectory
  """
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
    
# Function to evaluate: accuracy, precision, recall, f1-score
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
BATCH_SIZE = 32
TARGET_SIZE = (224, 224)
# Walk through each directory
dataset = "train"
walk_through_dir(dataset);
image_dir = Path(dataset)

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.JPG')) + list(image_dir.glob(r'**/*.jpg')) + list(image_dir.glob(r'**/*.png')) + list(image_dir.glob(r'**/*.png'))

labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)
image_df 

# Display 16 picture of the dataset with their labels
random_index = np.random.randint(0, len(image_df), 36)
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(14, 14),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[random_index[i]]))
    ax.set_title(image_df.Label[random_index[i]])
plt.tight_layout()
plt.show()
# Out:
# There are 525 directories and 0 images in 'train'.
# There are 0 directories and 163 images in 'train\ABBOTTS BABBLER'.
# There are 0 directories and 180 images in 'train\ABBOTTS BOOBY'.
# There are 0 directories and 179 images in 'train\ABYSSINIAN GROUND HORNBILL'.
# There are 0 directories and 135 images in 'train\AFRICAN CROWNED CRANE'.
# There are 0 directories and 154 images in 'train\AFRICAN EMERALD CUCKOO'.
# There are 0 directories and 137 images in 'train\AFRICAN FIREFINCH'.
# There are 0 directories and 155 images in 'train\AFRICAN OYSTER CATCHER'.
# There are 0 directories and 187 images in 'train\AFRICAN PIED HORNBILL'.
# There are 0 directories and 179 images in 'train\AFRICAN PYGMY GOOSE'.
# There are 0 directories and 132 images in 'train\ALBATROSS'.
# There are 0 directories and 161 images in 'train\ALBERTS TOWHEE'.
# There are 0 directories and 165 images in 'train\ALEXANDRINE PARAKEET'.
# There are 0 directories and 166 images in 'train\ALPINE CHOUGH'.
# There are 0 directories and 150 images in 'train\ALTAMIRA YELLOWTHROAT'.
# There are 0 directories and 179 images in 'train\AMERICAN AVOCET'.
# There are 0 directories and 170 images in 'train\AMERICAN BITTERN'.
# There are 0 directories and 158 images in 'train\AMERICAN COOT'.
# There are 0 directories and 193 images in 'train\AMERICAN DIPPER'.
# There are 0 directories and 164 images in 'train\AMERICAN FLAMINGO'.
# There are 0 directories and 133 images in 'train\AMERICAN GOLDFINCH'.
# There are 0 directories and 155 images in 'train\AMERICAN KESTREL'.
# There are 0 directories and 179 images in 'train\AMERICAN PIPIT'.
# There are 0 directories and 139 images in 'train\AMERICAN REDSTART'.
# There are 0 directories and 147 images in 'train\AMERICAN ROBIN'.
# There are 0 directories and 187 images in 'train\AMERICAN WIGEON'.
# There are 0 directories and 130 images in 'train\AMETHYST WOODSTAR'.
# There are 0 directories and 134 images in 'train\ANDEAN GOOSE'.
# There are 0 directories and 144 images in 'train\ANDEAN LAPWING'.
# There are 0 directories and 154 images in 'train\ANDEAN SISKIN'.
# There are 0 directories and 153 images in 'train\ANHINGA'.
# There are 0 directories and 150 images in 'train\ANIANIAU'.
# There are 0 directories and 139 images in 'train\ANNAS HUMMINGBIRD'.
# There are 0 directories and 150 images in 'train\ANTBIRD'.
# There are 0 directories and 139 images in 'train\ANTILLEAN EUPHONIA'.
# There are 0 directories and 154 images in 'train\APAPANE'.
# There are 0 directories and 153 images in 'train\APOSTLEBIRD'.
# There are 0 directories and 152 images in 'train\ARARIPE MANAKIN'.
# There are 0 directories and 188 images in 'train\ASHY STORM PETREL'.
# There are 0 directories and 164 images in 'train\ASHY THRUSHBIRD'.
# There are 0 directories and 156 images in 'train\ASIAN CRESTED IBIS'.
# There are 0 directories and 141 images in 'train\ASIAN DOLLARD BIRD'.
# There are 0 directories and 220 images in 'train\ASIAN GREEN BEE EATER'.
# There are 0 directories and 190 images in 'train\ASIAN OPENBILL STORK'.
# There are 0 directories and 187 images in 'train\AUCKLAND SHAQ'.
# There are 0 directories and 154 images in 'train\AUSTRAL CANASTERO'.
# There are 0 directories and 190 images in 'train\AUSTRALASIAN FIGBIRD'.
# There are 0 directories and 164 images in 'train\AVADAVAT'.
# There are 0 directories and 168 images in 'train\AZARAS SPINETAIL'.
# There are 0 directories and 141 images in 'train\AZURE BREASTED PITTA'.
# There are 0 directories and 136 images in 'train\AZURE JAY'.
# There are 0 directories and 137 images in 'train\AZURE TANAGER'.
# There are 0 directories and 165 images in 'train\AZURE TIT'.
# There are 0 directories and 150 images in 'train\BAIKAL TEAL'.
# There are 0 directories and 160 images in 'train\BALD EAGLE'.
# There are 0 directories and 152 images in 'train\BALD IBIS'.
# There are 0 directories and 132 images in 'train\BALI STARLING'.
# There are 0 directories and 137 images in 'train\BALTIMORE ORIOLE'.
# There are 0 directories and 165 images in 'train\BANANAQUIT'.
# There are 0 directories and 163 images in 'train\BAND TAILED GUAN'.
# There are 0 directories and 194 images in 'train\BANDED BROADBILL'.
# There are 0 directories and 166 images in 'train\BANDED PITA'.
# There are 0 directories and 153 images in 'train\BANDED STILT'.
# There are 0 directories and 168 images in 'train\BAR-TAILED GODWIT'.
# There are 0 directories and 158 images in 'train\BARN OWL'.
# There are 0 directories and 132 images in 'train\BARN SWALLOW'.
# There are 0 directories and 136 images in 'train\BARRED PUFFBIRD'.
# There are 0 directories and 132 images in 'train\BARROWS GOLDENEYE'.
# There are 0 directories and 143 images in 'train\BAY-BREASTED WARBLER'.
# There are 0 directories and 160 images in 'train\BEARDED BARBET'.
# There are 0 directories and 142 images in 'train\BEARDED BELLBIRD'.
# There are 0 directories and 144 images in 'train\BEARDED REEDLING'.
# There are 0 directories and 154 images in 'train\BELTED KINGFISHER'.
# There are 0 directories and 151 images in 'train\BIRD OF PARADISE'.
# There are 0 directories and 142 images in 'train\BLACK AND YELLOW BROADBILL'.
# There are 0 directories and 156 images in 'train\BLACK BAZA'.
# There are 0 directories and 172 images in 'train\BLACK BREASTED PUFFBIRD'.
# There are 0 directories and 132 images in 'train\BLACK COCKATO'.
# There are 0 directories and 162 images in 'train\BLACK FACED SPOONBILL'.
# There are 0 directories and 131 images in 'train\BLACK FRANCOLIN'.
# There are 0 directories and 181 images in 'train\BLACK HEADED CAIQUE'.
# There are 0 directories and 173 images in 'train\BLACK NECKED STILT'.
# There are 0 directories and 155 images in 'train\BLACK SKIMMER'.
# There are 0 directories and 164 images in 'train\BLACK SWAN'.
# There are 0 directories and 165 images in 'train\BLACK TAIL CRAKE'.
# There are 0 directories and 163 images in 'train\BLACK THROATED BUSHTIT'.
# There are 0 directories and 145 images in 'train\BLACK THROATED HUET'.
# There are 0 directories and 135 images in 'train\BLACK THROATED WARBLER'.
# There are 0 directories and 188 images in 'train\BLACK VENTED SHEARWATER'.
# There are 0 directories and 156 images in 'train\BLACK VULTURE'.
# There are 0 directories and 133 images in 'train\BLACK-CAPPED CHICKADEE'.
# There are 0 directories and 137 images in 'train\BLACK-NECKED GREBE'.
# There are 0 directories and 168 images in 'train\BLACK-THROATED SPARROW'.
# There are 0 directories and 134 images in 'train\BLACKBURNIAM WARBLER'.
# There are 0 directories and 144 images in 'train\BLONDE CRESTED WOODPECKER'.
# There are 0 directories and 153 images in 'train\BLOOD PHEASANT'.
# There are 0 directories and 155 images in 'train\BLUE COAU'.
# There are 0 directories and 173 images in 'train\BLUE DACNIS'.
# There are 0 directories and 195 images in 'train\BLUE GRAY GNATCATCHER'.
# There are 0 directories and 170 images in 'train\BLUE GROSBEAK'.
# There are 0 directories and 185 images in 'train\BLUE GROUSE'.
# There are 0 directories and 167 images in 'train\BLUE HERON'.
# There are 0 directories and 186 images in 'train\BLUE MALKOHA'.
# There are 0 directories and 198 images in 'train\BLUE THROATED PIPING GUAN'.
# There are 0 directories and 150 images in 'train\BLUE THROATED TOUCANET'.
# There are 0 directories and 157 images in 'train\BOBOLINK'.
# There are 0 directories and 154 images in 'train\BORNEAN BRISTLEHEAD'.
# There are 0 directories and 160 images in 'train\BORNEAN LEAFBIRD'.
# There are 0 directories and 152 images in 'train\BORNEAN PHEASANT'.
# There are 0 directories and 154 images in 'train\BRANDT CORMARANT'.
# There are 0 directories and 183 images in 'train\BREWERS BLACKBIRD'.
# There are 0 directories and 177 images in 'train\BROWN CREPPER'.
# There are 0 directories and 192 images in 'train\BROWN HEADED COWBIRD'.
# There are 0 directories and 154 images in 'train\BROWN NOODY'.
# There are 0 directories and 163 images in 'train\BROWN THRASHER'.
# There are 0 directories and 184 images in 'train\BUFFLEHEAD'.
# There are 0 directories and 155 images in 'train\BULWERS PHEASANT'.
# There are 0 directories and 143 images in 'train\BURCHELLS COURSER'.
# There are 0 directories and 160 images in 'train\BUSH TURKEY'.
# There are 0 directories and 155 images in 'train\CAATINGA CACHOLOTE'.
# There are 0 directories and 177 images in 'train\CABOTS TRAGOPAN'.
# There are 0 directories and 162 images in 'train\CACTUS WREN'.
# There are 0 directories and 152 images in 'train\CALIFORNIA CONDOR'.
# There are 0 directories and 160 images in 'train\CALIFORNIA GULL'.
# There are 0 directories and 161 images in 'train\CALIFORNIA QUAIL'.
# There are 0 directories and 197 images in 'train\CAMPO FLICKER'.
# There are 0 directories and 160 images in 'train\CANARY'.
# There are 0 directories and 185 images in 'train\CANVASBACK'.
# There are 0 directories and 154 images in 'train\CAPE GLOSSY STARLING'.
# There are 0 directories and 133 images in 'train\CAPE LONGCLAW'.
# There are 0 directories and 149 images in 'train\CAPE MAY WARBLER'.
# There are 0 directories and 155 images in 'train\CAPE ROCK THRUSH'.
# There are 0 directories and 137 images in 'train\CAPPED HERON'.
# There are 0 directories and 133 images in 'train\CAPUCHINBIRD'.
# There are 0 directories and 162 images in 'train\CARMINE BEE-EATER'.
# There are 0 directories and 213 images in 'train\CASPIAN TERN'.
# There are 0 directories and 160 images in 'train\CASSOWARY'.
# There are 0 directories and 180 images in 'train\CEDAR WAXWING'.
# There are 0 directories and 163 images in 'train\CERULEAN WARBLER'.
# There are 0 directories and 153 images in 'train\CHARA DE COLLAR'.
# There are 0 directories and 137 images in 'train\CHATTERING LORY'.
# There are 0 directories and 132 images in 'train\CHESTNET BELLIED EUPHONIA'.
# There are 0 directories and 170 images in 'train\CHESTNUT WINGED CUCKOO'.
# There are 0 directories and 165 images in 'train\CHINESE BAMBOO PARTRIDGE'.
# There are 0 directories and 144 images in 'train\CHINESE POND HERON'.
# There are 0 directories and 162 images in 'train\CHIPPING SPARROW'.
# There are 0 directories and 141 images in 'train\CHUCAO TAPACULO'.
# There are 0 directories and 167 images in 'train\CHUKAR PARTRIDGE'.
# There are 0 directories and 162 images in 'train\CINNAMON ATTILA'.
# There are 0 directories and 162 images in 'train\CINNAMON FLYCATCHER'.
# There are 0 directories and 161 images in 'train\CINNAMON TEAL'.
# There are 0 directories and 182 images in 'train\CLARKS GREBE'.
# There are 0 directories and 161 images in 'train\CLARKS NUTCRACKER'.
# There are 0 directories and 163 images in 'train\COCK OF THE  ROCK'.
# There are 0 directories and 166 images in 'train\COCKATOO'.
# There are 0 directories and 177 images in 'train\COLLARED ARACARI'.
# There are 0 directories and 172 images in 'train\COLLARED CRESCENTCHEST'.
# There are 0 directories and 139 images in 'train\COMMON FIRECREST'.
# There are 0 directories and 177 images in 'train\COMMON GRACKLE'.
# There are 0 directories and 157 images in 'train\COMMON HOUSE MARTIN'.
# There are 0 directories and 133 images in 'train\COMMON IORA'.
# There are 0 directories and 161 images in 'train\COMMON LOON'.
# There are 0 directories and 161 images in 'train\COMMON POORWILL'.
# There are 0 directories and 141 images in 'train\COMMON STARLING'.
# There are 0 directories and 196 images in 'train\COPPERSMITH BARBET'.
# There are 0 directories and 144 images in 'train\COPPERY TAILED COUCAL'.
# There are 0 directories and 144 images in 'train\CRAB PLOVER'.
# There are 0 directories and 135 images in 'train\CRANE HAWK'.
# There are 0 directories and 139 images in 'train\CREAM COLORED WOODPECKER'.
# There are 0 directories and 160 images in 'train\CRESTED AUKLET'.
# There are 0 directories and 155 images in 'train\CRESTED CARACARA'.
# There are 0 directories and 152 images in 'train\CRESTED COUA'.
# There are 0 directories and 142 images in 'train\CRESTED FIREBACK'.
# There are 0 directories and 163 images in 'train\CRESTED KINGFISHER'.
# There are 0 directories and 152 images in 'train\CRESTED NUTHATCH'.
# There are 0 directories and 164 images in 'train\CRESTED OROPENDOLA'.
# There are 0 directories and 181 images in 'train\CRESTED SERPENT EAGLE'.
# There are 0 directories and 156 images in 'train\CRESTED SHRIKETIT'.
# There are 0 directories and 197 images in 'train\CRESTED WOOD PARTRIDGE'.
# There are 0 directories and 154 images in 'train\CRIMSON CHAT'.
# There are 0 directories and 198 images in 'train\CRIMSON SUNBIRD'.
# There are 0 directories and 163 images in 'train\CROW'.
# There are 0 directories and 162 images in 'train\CUBAN TODY'.
# There are 0 directories and 138 images in 'train\CUBAN TROGON'.
# There are 0 directories and 137 images in 'train\CURL CRESTED ARACURI'.
# There are 0 directories and 233 images in 'train\D-ARNAUDS BARBET'.
# There are 0 directories and 159 images in 'train\DALMATIAN PELICAN'.
# There are 0 directories and 136 images in 'train\DARJEELING WOODPECKER'.
# There are 0 directories and 203 images in 'train\DARK EYED JUNCO'.
# There are 0 directories and 146 images in 'train\DAURIAN REDSTART'.
# There are 0 directories and 139 images in 'train\DEMOISELLE CRANE'.
# There are 0 directories and 148 images in 'train\DOUBLE BARRED FINCH'.
# There are 0 directories and 185 images in 'train\DOUBLE BRESTED CORMARANT'.
# There are 0 directories and 166 images in 'train\DOUBLE EYED FIG PARROT'.
# There are 0 directories and 157 images in 'train\DOWNY WOODPECKER'.
# There are 0 directories and 190 images in 'train\DUNLIN'.
# There are 0 directories and 139 images in 'train\DUSKY LORY'.
# There are 0 directories and 140 images in 'train\DUSKY ROBIN'.
# There are 0 directories and 154 images in 'train\EARED PITA'.
# There are 0 directories and 154 images in 'train\EASTERN BLUEBIRD'.
# There are 0 directories and 134 images in 'train\EASTERN BLUEBONNET'.
# There are 0 directories and 152 images in 'train\EASTERN GOLDEN WEAVER'.
# There are 0 directories and 190 images in 'train\EASTERN MEADOWLARK'.
# There are 0 directories and 160 images in 'train\EASTERN ROSELLA'.
# There are 0 directories and 157 images in 'train\EASTERN TOWEE'.
# There are 0 directories and 150 images in 'train\EASTERN WIP POOR WILL'.
# There are 0 directories and 205 images in 'train\EASTERN YELLOW ROBIN'.
# There are 0 directories and 139 images in 'train\ECUADORIAN HILLSTAR'.
# There are 0 directories and 157 images in 'train\EGYPTIAN GOOSE'.
# There are 0 directories and 144 images in 'train\ELEGANT TROGON'.
# There are 0 directories and 162 images in 'train\ELLIOTS  PHEASANT'.
# There are 0 directories and 139 images in 'train\EMERALD TANAGER'.
# There are 0 directories and 152 images in 'train\EMPEROR PENGUIN'.
# There are 0 directories and 163 images in 'train\EMU'.
# There are 0 directories and 165 images in 'train\ENGGANO MYNA'.
# There are 0 directories and 166 images in 'train\EURASIAN BULLFINCH'.
# There are 0 directories and 130 images in 'train\EURASIAN GOLDEN ORIOLE'.
# There are 0 directories and 154 images in 'train\EURASIAN MAGPIE'.
# There are 0 directories and 135 images in 'train\EUROPEAN GOLDFINCH'.
# There are 0 directories and 138 images in 'train\EUROPEAN TURTLE DOVE'.
# There are 0 directories and 144 images in 'train\EVENING GROSBEAK'.
# There are 0 directories and 160 images in 'train\FAIRY BLUEBIRD'.
# There are 0 directories and 154 images in 'train\FAIRY PENGUIN'.
# There are 0 directories and 136 images in 'train\FAIRY TERN'.
# There are 0 directories and 150 images in 'train\FAN TAILED WIDOW'.
# There are 0 directories and 150 images in 'train\FASCIATED WREN'.
# There are 0 directories and 150 images in 'train\FIERY MINIVET'.
# There are 0 directories and 152 images in 'train\FIORDLAND PENGUIN'.
# There are 0 directories and 150 images in 'train\FIRE TAILLED MYZORNIS'.
# There are 0 directories and 162 images in 'train\FLAME BOWERBIRD'.
# There are 0 directories and 177 images in 'train\FLAME TANAGER'.
# There are 0 directories and 172 images in 'train\FOREST WAGTAIL'.
# There are 0 directories and 159 images in 'train\FRIGATE'.
# There are 0 directories and 209 images in 'train\FRILL BACK PIGEON'.
# There are 0 directories and 153 images in 'train\GAMBELS QUAIL'.
# There are 0 directories and 142 images in 'train\GANG GANG COCKATOO'.
# There are 0 directories and 155 images in 'train\GILA WOODPECKER'.
# There are 0 directories and 138 images in 'train\GILDED FLICKER'.
# There are 0 directories and 175 images in 'train\GLOSSY IBIS'.
# There are 0 directories and 131 images in 'train\GO AWAY BIRD'.
# There are 0 directories and 159 images in 'train\GOLD WING WARBLER'.
# There are 0 directories and 140 images in 'train\GOLDEN BOWER BIRD'.
# There are 0 directories and 176 images in 'train\GOLDEN CHEEKED WARBLER'.
# There are 0 directories and 135 images in 'train\GOLDEN CHLOROPHONIA'.
# There are 0 directories and 158 images in 'train\GOLDEN EAGLE'.
# There are 0 directories and 150 images in 'train\GOLDEN PARAKEET'.
# There are 0 directories and 159 images in 'train\GOLDEN PHEASANT'.
# There are 0 directories and 158 images in 'train\GOLDEN PIPIT'.
# There are 0 directories and 155 images in 'train\GOULDIAN FINCH'.
# There are 0 directories and 152 images in 'train\GRANDALA'.
# There are 0 directories and 155 images in 'train\GRAY CATBIRD'.
# There are 0 directories and 164 images in 'train\GRAY KINGBIRD'.
# There are 0 directories and 160 images in 'train\GRAY PARTRIDGE'.
# There are 0 directories and 189 images in 'train\GREAT ARGUS'.
# There are 0 directories and 144 images in 'train\GREAT GRAY OWL'.
# There are 0 directories and 163 images in 'train\GREAT JACAMAR'.
# There are 0 directories and 169 images in 'train\GREAT KISKADEE'.
# There are 0 directories and 138 images in 'train\GREAT POTOO'.
# There are 0 directories and 165 images in 'train\GREAT TINAMOU'.
# There are 0 directories and 149 images in 'train\GREAT XENOPS'.
# There are 0 directories and 157 images in 'train\GREATER PEWEE'.
# There are 0 directories and 203 images in 'train\GREATER PRAIRIE CHICKEN'.
# There are 0 directories and 184 images in 'train\GREATOR SAGE GROUSE'.
# There are 0 directories and 140 images in 'train\GREEN BROADBILL'.
# There are 0 directories and 156 images in 'train\GREEN JAY'.
# There are 0 directories and 176 images in 'train\GREEN MAGPIE'.
# There are 0 directories and 154 images in 'train\GREEN WINGED DOVE'.
# There are 0 directories and 159 images in 'train\GREY CUCKOOSHRIKE'.
# There are 0 directories and 199 images in 'train\GREY HEADED CHACHALACA'.
# There are 0 directories and 143 images in 'train\GREY HEADED FISH EAGLE'.
# There are 0 directories and 158 images in 'train\GREY PLOVER'.
# There are 0 directories and 155 images in 'train\GROVED BILLED ANI'.
# There are 0 directories and 162 images in 'train\GUINEA TURACO'.
# There are 0 directories and 137 images in 'train\GUINEAFOWL'.
# There are 0 directories and 162 images in 'train\GURNEYS PITTA'.
# There are 0 directories and 162 images in 'train\GYRFALCON'.
# There are 0 directories and 163 images in 'train\HAMERKOP'.
# There are 0 directories and 151 images in 'train\HARLEQUIN DUCK'.
# There are 0 directories and 134 images in 'train\HARLEQUIN QUAIL'.
# There are 0 directories and 175 images in 'train\HARPY EAGLE'.
# There are 0 directories and 160 images in 'train\HAWAIIAN GOOSE'.
# There are 0 directories and 167 images in 'train\HAWFINCH'.
# There are 0 directories and 160 images in 'train\HELMET VANGA'.
# There are 0 directories and 160 images in 'train\HEPATIC TANAGER'.
# There are 0 directories and 150 images in 'train\HIMALAYAN BLUETAIL'.
# There are 0 directories and 151 images in 'train\HIMALAYAN MONAL'.
# There are 0 directories and 155 images in 'train\HOATZIN'.
# There are 0 directories and 135 images in 'train\HOODED MERGANSER'.
# There are 0 directories and 155 images in 'train\HOOPOES'.
# There are 0 directories and 157 images in 'train\HORNED GUAN'.
# There are 0 directories and 173 images in 'train\HORNED LARK'.
# There are 0 directories and 149 images in 'train\HORNED SUNGEM'.
# There are 0 directories and 248 images in 'train\HOUSE FINCH'.
# There are 0 directories and 155 images in 'train\HOUSE SPARROW'.
# There are 0 directories and 165 images in 'train\HYACINTH MACAW'.
# There are 0 directories and 159 images in 'train\IBERIAN MAGPIE'.
# There are 0 directories and 141 images in 'train\IBISBILL'.
# There are 0 directories and 144 images in 'train\IMPERIAL SHAQ'.
# There are 0 directories and 163 images in 'train\INCA TERN'.
# There are 0 directories and 131 images in 'train\INDIAN BUSTARD'.
# There are 0 directories and 186 images in 'train\INDIAN PITTA'.
# There are 0 directories and 183 images in 'train\INDIAN ROLLER'.
# There are 0 directories and 150 images in 'train\INDIAN VULTURE'.
# There are 0 directories and 153 images in 'train\INDIGO BUNTING'.
# There are 0 directories and 152 images in 'train\INDIGO FLYCATCHER'.
# There are 0 directories and 161 images in 'train\INLAND DOTTEREL'.
# There are 0 directories and 149 images in 'train\IVORY BILLED ARACARI'.
# There are 0 directories and 156 images in 'train\IVORY GULL'.
# There are 0 directories and 155 images in 'train\IWI'.
# There are 0 directories and 143 images in 'train\JABIRU'.
# There are 0 directories and 159 images in 'train\JACK SNIPE'.
# There are 0 directories and 204 images in 'train\JACOBIN PIGEON'.
# There are 0 directories and 162 images in 'train\JANDAYA PARAKEET'.
# There are 0 directories and 158 images in 'train\JAPANESE ROBIN'.
# There are 0 directories and 164 images in 'train\JAVA SPARROW'.
# There are 0 directories and 163 images in 'train\JOCOTOCO ANTPITTA'.
# There are 0 directories and 144 images in 'train\KAGU'.
# There are 0 directories and 154 images in 'train\KAKAPO'.
# There are 0 directories and 175 images in 'train\KILLDEAR'.
# There are 0 directories and 170 images in 'train\KING EIDER'.
# There are 0 directories and 136 images in 'train\KING VULTURE'.
# There are 0 directories and 138 images in 'train\KIWI'.
# There are 0 directories and 197 images in 'train\KNOB BILLED DUCK'.
# There are 0 directories and 143 images in 'train\KOOKABURRA'.
# There are 0 directories and 160 images in 'train\LARK BUNTING'.
# There are 0 directories and 206 images in 'train\LAUGHING GULL'.
# There are 0 directories and 157 images in 'train\LAZULI BUNTING'.
# There are 0 directories and 154 images in 'train\LESSER ADJUTANT'.
# There are 0 directories and 138 images in 'train\LILAC ROLLER'.
# There are 0 directories and 200 images in 'train\LIMPKIN'.
# There are 0 directories and 175 images in 'train\LITTLE AUK'.
# There are 0 directories and 190 images in 'train\LOGGERHEAD SHRIKE'.
# There are 0 directories and 160 images in 'train\LONG-EARED OWL'.
# There are 0 directories and 156 images in 'train\LOONEY BIRDS'.
# There are 0 directories and 168 images in 'train\LUCIFER HUMMINGBIRD'.
# There are 0 directories and 142 images in 'train\MAGPIE GOOSE'.
# There are 0 directories and 154 images in 'train\MALABAR HORNBILL'.
# There are 0 directories and 163 images in 'train\MALACHITE KINGFISHER'.
# There are 0 directories and 143 images in 'train\MALAGASY WHITE EYE'.
# There are 0 directories and 159 images in 'train\MALEO'.
# There are 0 directories and 135 images in 'train\MALLARD DUCK'.
# There are 0 directories and 154 images in 'train\MANDRIN DUCK'.
# There are 0 directories and 137 images in 'train\MANGROVE CUCKOO'.
# There are 0 directories and 197 images in 'train\MARABOU STORK'.
# There are 0 directories and 183 images in 'train\MASKED BOBWHITE'.
# There are 0 directories and 132 images in 'train\MASKED BOOBY'.
# There are 0 directories and 131 images in 'train\MASKED LAPWING'.
# There are 0 directories and 187 images in 'train\MCKAYS BUNTING'.
# There are 0 directories and 209 images in 'train\MERLIN'.
# There are 0 directories and 154 images in 'train\MIKADO  PHEASANT'.
# There are 0 directories and 208 images in 'train\MILITARY MACAW'.
# There are 0 directories and 153 images in 'train\MOURNING DOVE'.
# There are 0 directories and 141 images in 'train\MYNA'.
# There are 0 directories and 154 images in 'train\NICOBAR PIGEON'.
# There are 0 directories and 157 images in 'train\NOISY FRIARBIRD'.
# There are 0 directories and 185 images in 'train\NORTHERN BEARDLESS TYRANNULET'.
# There are 0 directories and 155 images in 'train\NORTHERN CARDINAL'.
# There are 0 directories and 139 images in 'train\NORTHERN FLICKER'.
# There are 0 directories and 137 images in 'train\NORTHERN FULMAR'.
# There are 0 directories and 154 images in 'train\NORTHERN GANNET'.
# There are 0 directories and 160 images in 'train\NORTHERN GOSHAWK'.
# There are 0 directories and 156 images in 'train\NORTHERN JACANA'.
# There are 0 directories and 140 images in 'train\NORTHERN MOCKINGBIRD'.
# There are 0 directories and 196 images in 'train\NORTHERN PARULA'.
# There are 0 directories and 130 images in 'train\NORTHERN RED BISHOP'.
# There are 0 directories and 153 images in 'train\NORTHERN SHOVELER'.
# There are 0 directories and 159 images in 'train\OCELLATED TURKEY'.
# There are 0 directories and 182 images in 'train\OILBIRD'.
# There are 0 directories and 160 images in 'train\OKINAWA RAIL'.
# There are 0 directories and 192 images in 'train\ORANGE BREASTED TROGON'.
# There are 0 directories and 132 images in 'train\ORANGE BRESTED BUNTING'.
# There are 0 directories and 157 images in 'train\ORIENTAL BAY OWL'.
# There are 0 directories and 208 images in 'train\ORNATE HAWK EAGLE'.
# There are 0 directories and 152 images in 'train\OSPREY'.
# There are 0 directories and 161 images in 'train\OSTRICH'.
# There are 0 directories and 233 images in 'train\OVENBIRD'.
# There are 0 directories and 207 images in 'train\OYSTER CATCHER'.
# There are 0 directories and 163 images in 'train\PAINTED BUNTING'.
# There are 0 directories and 160 images in 'train\PALILA'.
# There are 0 directories and 192 images in 'train\PALM NUT VULTURE'.
# There are 0 directories and 176 images in 'train\PARADISE TANAGER'.
# There are 0 directories and 155 images in 'train\PARAKETT  AUKLET'.
# There are 0 directories and 161 images in 'train\PARUS MAJOR'.
# There are 0 directories and 130 images in 'train\PATAGONIAN SIERRA FINCH'.
# There are 0 directories and 156 images in 'train\PEACOCK'.
# There are 0 directories and 156 images in 'train\PEREGRINE FALCON'.
# There are 0 directories and 188 images in 'train\PHAINOPEPLA'.
# There are 0 directories and 154 images in 'train\PHILIPPINE EAGLE'.
# There are 0 directories and 154 images in 'train\PINK ROBIN'.
# There are 0 directories and 200 images in 'train\PLUSH CRESTED JAY'.
# There are 0 directories and 140 images in 'train\POMARINE JAEGER'.
# There are 0 directories and 166 images in 'train\PUFFIN'.
# There are 0 directories and 185 images in 'train\PUNA TEAL'.
# There are 0 directories and 153 images in 'train\PURPLE FINCH'.
# There are 0 directories and 153 images in 'train\PURPLE GALLINULE'.
# There are 0 directories and 160 images in 'train\PURPLE MARTIN'.
# There are 0 directories and 154 images in 'train\PURPLE SWAMPHEN'.
# There are 0 directories and 173 images in 'train\PYGMY KINGFISHER'.
# There are 0 directories and 209 images in 'train\PYRRHULOXIA'.
# There are 0 directories and 152 images in 'train\QUETZAL'.
# There are 0 directories and 140 images in 'train\RAINBOW LORIKEET'.
# There are 0 directories and 193 images in 'train\RAZORBILL'.
# There are 0 directories and 197 images in 'train\RED BEARDED BEE EATER'.
# There are 0 directories and 146 images in 'train\RED BELLIED PITTA'.
# There are 0 directories and 212 images in 'train\RED BILLED TROPICBIRD'.
# There are 0 directories and 136 images in 'train\RED BROWED FINCH'.
# There are 0 directories and 191 images in 'train\RED CROSSBILL'.
# There are 0 directories and 153 images in 'train\RED FACED CORMORANT'.
# There are 0 directories and 167 images in 'train\RED FACED WARBLER'.
# There are 0 directories and 167 images in 'train\RED FODY'.
# There are 0 directories and 160 images in 'train\RED HEADED DUCK'.
# There are 0 directories and 133 images in 'train\RED HEADED WOODPECKER'.
# There are 0 directories and 200 images in 'train\RED KNOT'.
# There are 0 directories and 169 images in 'train\RED LEGGED HONEYCREEPER'.
# There are 0 directories and 159 images in 'train\RED NAPED TROGON'.
# There are 0 directories and 172 images in 'train\RED SHOULDERED HAWK'.
# There are 0 directories and 202 images in 'train\RED TAILED HAWK'.
# There are 0 directories and 130 images in 'train\RED TAILED THRUSH'.
# There are 0 directories and 152 images in 'train\RED WINGED BLACKBIRD'.
# There are 0 directories and 162 images in 'train\RED WISKERED BULBUL'.
# There are 0 directories and 164 images in 'train\REGENT BOWERBIRD'.
# There are 0 directories and 152 images in 'train\RING-NECKED PHEASANT'.
# There are 0 directories and 160 images in 'train\ROADRUNNER'.
# There are 0 directories and 132 images in 'train\ROCK DOVE'.
# There are 0 directories and 197 images in 'train\ROSE BREASTED COCKATOO'.
# There are 0 directories and 174 images in 'train\ROSE BREASTED GROSBEAK'.
# There are 0 directories and 193 images in 'train\ROSEATE SPOONBILL'.
# There are 0 directories and 139 images in 'train\ROSY FACED LOVEBIRD'.
# There are 0 directories and 152 images in 'train\ROUGH LEG BUZZARD'.
# There are 0 directories and 142 images in 'train\ROYAL FLYCATCHER'.
# There are 0 directories and 186 images in 'train\RUBY CROWNED KINGLET'.
# There are 0 directories and 135 images in 'train\RUBY THROATED HUMMINGBIRD'.
# There are 0 directories and 163 images in 'train\RUDDY SHELDUCK'.
# There are 0 directories and 160 images in 'train\RUDY KINGFISHER'.
# There are 0 directories and 156 images in 'train\RUFOUS KINGFISHER'.
# There are 0 directories and 263 images in 'train\RUFOUS TREPE'.
# There are 0 directories and 189 images in 'train\RUFUOS MOTMOT'.
# There are 0 directories and 153 images in 'train\SAMATRAN THRUSH'.
# There are 0 directories and 151 images in 'train\SAND MARTIN'.
# There are 0 directories and 156 images in 'train\SANDHILL CRANE'.
# There are 0 directories and 169 images in 'train\SATYR TRAGOPAN'.
# There are 0 directories and 197 images in 'train\SAYS PHOEBE'.
# There are 0 directories and 154 images in 'train\SCARLET CROWNED FRUIT DOVE'.
# There are 0 directories and 160 images in 'train\SCARLET FACED LIOCICHLA'.
# There are 0 directories and 138 images in 'train\SCARLET IBIS'.
# There are 0 directories and 157 images in 'train\SCARLET MACAW'.
# There are 0 directories and 132 images in 'train\SCARLET TANAGER'.
# There are 0 directories and 175 images in 'train\SHOEBILL'.
# There are 0 directories and 164 images in 'train\SHORT BILLED DOWITCHER'.
# There are 0 directories and 160 images in 'train\SMITHS LONGSPUR'.
# There are 0 directories and 190 images in 'train\SNOW GOOSE'.
# There are 0 directories and 175 images in 'train\SNOW PARTRIDGE'.
# There are 0 directories and 132 images in 'train\SNOWY EGRET'.
# There are 0 directories and 161 images in 'train\SNOWY OWL'.
# There are 0 directories and 130 images in 'train\SNOWY PLOVER'.
# There are 0 directories and 187 images in 'train\SNOWY SHEATHBILL'.
# There are 0 directories and 200 images in 'train\SORA'.
# There are 0 directories and 160 images in 'train\SPANGLED COTINGA'.
# There are 0 directories and 161 images in 'train\SPLENDID WREN'.
# There are 0 directories and 144 images in 'train\SPOON BILED SANDPIPER'.
# There are 0 directories and 150 images in 'train\SPOTTED CATBIRD'.
# There are 0 directories and 184 images in 'train\SPOTTED WHISTLING DUCK'.
# There are 0 directories and 152 images in 'train\SQUACCO HERON'.
# There are 0 directories and 161 images in 'train\SRI LANKA BLUE MAGPIE'.
# There are 0 directories and 160 images in 'train\STEAMER DUCK'.
# There are 0 directories and 135 images in 'train\STORK BILLED KINGFISHER'.
# There are 0 directories and 196 images in 'train\STRIATED CARACARA'.
# There are 0 directories and 143 images in 'train\STRIPED OWL'.
# There are 0 directories and 144 images in 'train\STRIPPED MANAKIN'.
# There are 0 directories and 160 images in 'train\STRIPPED SWALLOW'.
# There are 0 directories and 169 images in 'train\SUNBITTERN'.
# There are 0 directories and 154 images in 'train\SUPERB STARLING'.
# There are 0 directories and 185 images in 'train\SURF SCOTER'.
# There are 0 directories and 216 images in 'train\SWINHOES PHEASANT'.
# There are 0 directories and 141 images in 'train\TAILORBIRD'.
# There are 0 directories and 136 images in 'train\TAIWAN MAGPIE'.
# There are 0 directories and 161 images in 'train\TAKAHE'.
# There are 0 directories and 131 images in 'train\TASMANIAN HEN'.
# There are 0 directories and 187 images in 'train\TAWNY FROGMOUTH'.
# There are 0 directories and 155 images in 'train\TEAL DUCK'.
# There are 0 directories and 154 images in 'train\TIT MOUSE'.
# There are 0 directories and 136 images in 'train\TOUCHAN'.
# There are 0 directories and 165 images in 'train\TOWNSENDS WARBLER'.
# There are 0 directories and 181 images in 'train\TREE SWALLOW'.
# There are 0 directories and 139 images in 'train\TRICOLORED BLACKBIRD'.
# There are 0 directories and 154 images in 'train\TROPICAL KINGBIRD'.
# There are 0 directories and 137 images in 'train\TRUMPTER SWAN'.
# There are 0 directories and 163 images in 'train\TURKEY VULTURE'.
# There are 0 directories and 156 images in 'train\TURQUOISE MOTMOT'.
# There are 0 directories and 155 images in 'train\UMBRELLA BIRD'.
# There are 0 directories and 193 images in 'train\VARIED THRUSH'.
# There are 0 directories and 190 images in 'train\VEERY'.
# There are 0 directories and 152 images in 'train\VENEZUELIAN TROUPIAL'.
# There are 0 directories and 182 images in 'train\VERDIN'.
# There are 0 directories and 155 images in 'train\VERMILION FLYCATHER'.
# There are 0 directories and 151 images in 'train\VICTORIA CROWNED PIGEON'.
# There are 0 directories and 201 images in 'train\VIOLET BACKED STARLING'.
# There are 0 directories and 175 images in 'train\VIOLET CUCKOO'.
# There are 0 directories and 201 images in 'train\VIOLET GREEN SWALLOW'.
# There are 0 directories and 162 images in 'train\VIOLET TURACO'.
# There are 0 directories and 163 images in 'train\VISAYAN HORNBILL'.
# There are 0 directories and 169 images in 'train\VULTURINE GUINEAFOWL'.
# There are 0 directories and 172 images in 'train\WALL CREAPER'.
# There are 0 directories and 138 images in 'train\WATTLED CURASSOW'.
# There are 0 directories and 142 images in 'train\WATTLED LAPWING'.
# There are 0 directories and 138 images in 'train\WHIMBREL'.
# There are 0 directories and 161 images in 'train\WHITE BREASTED WATERHEN'.
# There are 0 directories and 154 images in 'train\WHITE BROWED CRAKE'.
# There are 0 directories and 153 images in 'train\WHITE CHEEKED TURACO'.
# There are 0 directories and 159 images in 'train\WHITE CRESTED HORNBILL'.
# There are 0 directories and 176 images in 'train\WHITE EARED HUMMINGBIRD'.
# There are 0 directories and 160 images in 'train\WHITE NECKED RAVEN'.
# There are 0 directories and 175 images in 'train\WHITE TAILED TROPIC'.
# There are 0 directories and 164 images in 'train\WHITE THROATED BEE EATER'.
# There are 0 directories and 153 images in 'train\WILD TURKEY'.
# There are 0 directories and 195 images in 'train\WILLOW PTARMIGAN'.
# There are 0 directories and 155 images in 'train\WILSONS BIRD OF PARADISE'.
# There are 0 directories and 214 images in 'train\WOOD DUCK'.
# There are 0 directories and 211 images in 'train\WOOD THRUSH'.
# There are 0 directories and 194 images in 'train\WOODLAND KINGFISHER'.
# There are 0 directories and 193 images in 'train\WRENTIT'.
# There are 0 directories and 154 images in 'train\YELLOW BELLIED FLOWERPECKER'.
# There are 0 directories and 202 images in 'train\YELLOW BREASTED CHAT'.
# There are 0 directories and 155 images in 'train\YELLOW CACIQUE'.
# There are 0 directories and 159 images in 'train\YELLOW HEADED BLACKBIRD'.
# There are 0 directories and 170 images in 'train\ZEBRA DOVE'.

# %%
# Parameters
base_directory = 'test'
num_species_to_test = 10 
model_path = 'final_birds_classification_model.h5'

# Load model
model = load_model(model_path)

# Preprocess function
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(224, 224)) 
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img) 
    return img

all_species = os.listdir(base_directory)
selected_species = random.sample(all_species, num_species_to_test)

image_paths = []
labels = []

for species in selected_species:
    species_folder = os.path.join(base_directory, species)
    images = os.listdir(species_folder)
    for image in images:
        image_paths.append(os.path.join(species_folder, image))
        labels.append(species)


predicted_labels = []

for image_path in image_paths:
    img = preprocess_image(image_path)
    prediction = model.predict(img)
    predicted_label = np.argmax(prediction, axis=1)[0]
    predicted_labels.append(predicted_label)


label_encoder = LabelEncoder()
true_labels = label_encoder.fit_transform(labels)
predicted_labels = np.array(predicted_labels)


accuracy = np.mean(predicted_labels == true_labels)
print(f"Accuracy: {accuracy}")


target_names = label_encoder.classes_

cm = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10,10))
sns.heatmap(cm, annot=True, fmt="d", xticklabels=target_names, yticklabels=target_names)
plt.title('Confusion Matrix')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# Accuracy: 0.0
